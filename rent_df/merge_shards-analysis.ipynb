# %% [markdown]
# # Merging Shards
#
# ## Data
#
# ### Why is data in shards?
#
# The data Is in shards because the API would not let us continuously hit it even with long intervals, so the fetching script was changed to resemble mapper reducer. We manually implemented a job system and these jobs could run on different networks at the same time.
#
# ### What the data looks like?
#
# Data given by the API comes with six lists in which two of them are just hashes, which can be dropped without any problems. There is a list which is titled "for you", which we think is about specific recommendations for a user. We also drop that.
#
# We combine listings by IDs buildings with multiple apartments have different IDs And if the complete house is available for rent, it has a different ID attribute.
#
# Each apartment will be treated as a separate listing.

# %%
import pandas as pd
import json
import pathlib
from typing import Callable, TypeVar, Optional
from collections.abc import Iterable
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def process_single_file(path:pathlib.Path):
    with open(path, 'r') as f:
        data = json.load(f)
        all_entries = []

    for key, value in data.items():
        if key == "mapResults" or key == 'listResults':
            all_entries.extend(value)

    filtered_entries = [
        entry for entry in all_entries if 'detailUrl' in entry and 'homedetails' in entry['detailUrl']
    ]

    my_df = pd.DataFrame(filtered_entries)

    return my_df

# %%
big_df = pd.DataFrame()

shards = pathlib.Path('Data/Data Shards')
for x in shards.glob("**/*.json"):
    temp_df = process_single_file(x)
    big_df = pd.concat([big_df, temp_df], ignore_index=True)

# %%
big_df.head()
# Out:
#          zpid          id rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0  2081331532  2081331532         ForRent                    For Rent
# 1   440689351   440689351         ForRent                    For Rent
# 2   442762524   442762524         ForRent                    For Rent
# 3  2077973303  2077973303         ForRent                    For Rent
# 4    30629385    30629385         ForRent                    For Rent
#
#   providerListingId                                             imgSrc  \
# 0      g3qqbttyw1g7  https://photos.zillowstatic.com/fp/0f678de9f33...
# 1     4msp054rpy0w3  https://photos.zillowstatic.com/fp/e54dce7afc0...
# 2     56cyrsnd6f4z1  https://photos.zillowstatic.com/fp/2eab327f7e9...
# 3     1v8znm7bxz78f  https://photos.zillowstatic.com/fp/05657172691...
# 4     5at3ufj2pccje  https://photos.zillowstatic.com/fp/94b3e03c781...
#
#   hasImage                                          detailUrl statusType  \
# 0     True  https://www.zillow.com/homedetails/498-Jeffers...   FOR_RENT
# 1     True  https://www.zillow.com/homedetails/371-Koscius...   FOR_RENT
# 2     True  https://www.zillow.com/homedetails/373-Koscius...   FOR_RENT
# 3     True  https://www.zillow.com/homedetails/48-Jefferso...   FOR_RENT
# 4     True  https://www.zillow.com/homedetails/573-Evergre...   FOR_RENT
#
#            statusText  ... canSaveBuilding availabilityCount  \
# 0  Apartment for rent  ...             NaN               NaN
# 1  Apartment for rent  ...             NaN               NaN
# 2  Apartment for rent  ...             NaN               NaN
# 3  Apartment for rent  ...             NaN               NaN
# 4  Apartment for rent  ...             NaN               NaN
#
#    isInstantTourEnabled isContactable plid minBeds minBaths buildingId  \
# 0                   NaN           NaN  NaN     NaN      NaN        NaN
# 1                   NaN           NaN  NaN     NaN      NaN        NaN
# 2                   NaN           NaN  NaN     NaN      NaN        NaN
# 3                   NaN           NaN  NaN     NaN      NaN        NaN
# 4                   NaN           NaN  NaN     NaN      NaN        NaN
#
#   unitCount  minArea
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      NaN
# 4       NaN      NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# ## Duplicates
#
# There might be duplicates as zillow mihgt give us properties which spanned multiple zipcodes or happened to be on edge of zip codes. We drop duplicated so there is only one listing per property

# %%
if big_df['zpid'].duplicated().any():
    print("Duplicate addresses found!")
else:
    print("No duplicate addresses.")
# Out:
# Duplicate addresses found!

# %%
print(f"We had {big_df.shape[0]} entries before removing duplicates.")
big_df = big_df.drop_duplicates(subset='zpid', keep='first')
print(f"We have {big_df.shape[0]} entries after removing duplicates.")
# Out:
# We had 46796 entries before removing duplicates.
# We have 18254 entries after removing duplicates.

# %% [markdown]
# ### Unique ZillowID but same Addresses what??
#
# We find that there are some listings without a disclosed address. These would be lost if we would have used uniqeu addresses

# %%
duplicates_by_address = big_df[big_df.duplicated(subset=['address'], keep=False)]
print("Duplicates by Address:")
duplicates_by_address.head()
# Out:
# Duplicates by Address:
#            zpid          id rawHomeStatusCd marketingStatusSimplifiedCd  \
# 428  2100634408  2100634408         ForRent                    For Rent
# 431   442405589   442405589         ForRent                    For Rent
# 432  2056770390  2056770390         ForRent                    For Rent
# 434  2083184622  2083184622         ForRent                    For Rent
# 441  2094562201  2094562201         ForRent                    For Rent
#
#     providerListingId                                             imgSrc  \
# 428     1szmn2kdvd58h  https://photos.zillowstatic.com/fp/5a8d7af6094...
# 431      uf51mw0t307h  https://photos.zillowstatic.com/fp/c8c28aeb8db...
# 432      ksqhwbp2kzrv  https://photos.zillowstatic.com/fp/1066ac625cc...
# 434     5ccze5nmyv024  https://photos.zillowstatic.com/fp/6125d7d52e9...
# 441      35ukrtqwvxsv  https://photos.zillowstatic.com/fp/2508de21cac...
#
#     hasImage                                          detailUrl statusType  \
# 428     True  https://www.zillow.com/homedetails/West-Harris...   FOR_RENT
# 431     True  https://www.zillow.com/homedetails/West-Harris...   FOR_RENT
# 432     True  https://www.zillow.com/homedetails/White-Plain...   FOR_RENT
# 434     True  https://www.zillow.com/homedetails/White-Plain...   FOR_RENT
# 441     True  https://www.zillow.com/homedetails/White-Plain...   FOR_RENT
#
#              statusText  ... canSaveBuilding availabilityCount  \
# 428  Apartment for rent  ...             NaN               NaN
# 431  Apartment for rent  ...             NaN               NaN
# 432  Apartment for rent  ...             NaN               NaN
# 434  Apartment for rent  ...             NaN               NaN
# 441  Apartment for rent  ...             NaN               NaN
#
#      isInstantTourEnabled isContactable plid minBeds minBaths buildingId  \
# 428                   NaN           NaN  NaN     NaN      NaN        NaN
# 431                   NaN           NaN  NaN     NaN      NaN        NaN
# 432                   NaN           NaN  NaN     NaN      NaN        NaN
# 434                   NaN           NaN  NaN     NaN      NaN        NaN
# 441                   NaN           NaN  NaN     NaN      NaN        NaN
#
#     unitCount  minArea
# 428       NaN      NaN
# 431       NaN      NaN
# 432       NaN      NaN
# 434       NaN      NaN
# 441       NaN      NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# # ZIP-CODE DF Changes

# %%
zip_code_df = pd.read_csv('../ny_rent_prediction_data_comprehensive.csv')

# %%
# Look for missing values
print('total null values \n', zip_code_df.isnull().sum())

# Look for weird or outlier values in each column
for column in zip_code_df.columns:
  print(f"\nExploring column: {column}")
  print(zip_code_df[column].value_counts())
  if pd.api.types.is_numeric_dtype(zip_code_df[column]):
    plt.figure()
    zip_code_df[column].hist()
    plt.title(f"Histogram of {column}")
    plt.show()

# %%
rows_with_negative_666666 = zip_code_df[(zip_code_df == -666666666).any(axis=1)]

zip_code_df_cleaned = zip_code_df[(zip_code_df != -666666666).all(axis=1)]

print("Dropped rows:")
print(rows_with_negative_666666)
# Out:
# Dropped rows:
#      Total Population   Median Age  Male Population  Female Population  \
# 17                  0 -666666666.0                0                  0
# 34              19138         39.3             8426              10712
# 48                  0 -666666666.0                0                  0
# 118                 0 -666666666.0                0                  0
# 130                 0 -666666666.0                0                  0
#
#      White Alone  Black or African American Alone  Asian Alone  \
# 17             0                                0            0
# 34          2544                            12593          731
# 48             0                                0            0
# 118            0                                0            0
# 130            0                                0            0
#
#      Hispanic or Latino  Number of Households  Median Household Income  ...  \
# 17                    0                     0               -666666666  ...
# 34                 3783                 10103                    50177  ...
# 48                    0                     0               -666666666  ...
# 118                   0                     0               -666666666  ...
# 130                   0                     0               -666666666  ...
#
#      Monthly Housing Costs  High School Graduate (Age 25+)  \
# 17              -666666666                               0
# 34                    1457                            2591
# 48              -666666666                               0
# 118             -666666666                               0
# 130             -666666666                               0
#
#      Bachelor’s Degree (Age 25+)  Graduate or Professional Degree (Age 25+)  \
# 17                             0                                          0
# 34                          3638                                        155
# 48                             0                                          0
# 118                            0                                          0
# 130                            0                                          0
#
#      English Only  Spanish  Never Married  Currently Married  Divorced  \
# 17            NaN      NaN              0                  0         0
# 34            NaN      NaN           4046               2031       479
# 48            NaN      NaN              0                  0         0
# 118           NaN      NaN              0                  0         0
# 130           NaN      NaN              0                  0         0
#
#      zip code tabulation area
# 17                      10020
# 34                      10037
# 48                      10311
# 118                     11359
# 130                     11371
#
# [5 rows x 30 columns]

# %%
zip_code_df_cleaned.describe(include='all').T
# Out:
#                                            count           mean  \
# Total Population                           134.0   54022.746269
# Median Age                                 134.0      38.315672
# Male Population                            134.0   25978.917910
# Female Population                          134.0   28043.828358
# White Alone                                134.0   20875.261194
# Black or African American Alone            134.0   11954.022388
# Asian Alone                                134.0    7489.641791
# Hispanic or Latino                         134.0   16508.164179
# Number of Households                       134.0   20801.462687
# Median Household Income                    134.0   88444.783582
# Per Capita Income                          134.0   55473.246269
# Population Below Poverty Level             134.0    9681.858209
# Employed                                   134.0   25580.955224
# Unemployed                                 134.0    2096.761194
# Total Income Distribution                  134.0   20801.462687
# Median Gross Rent                          134.0    1885.656716
# Median Home Value                          134.0  835565.686567
# Occupied Housing Units                     134.0   20801.462687
# Vacant Housing Units                       134.0    2028.813433
# Owner-Occupied Units (value < $100,000)    134.0      82.850746
# Monthly Housing Costs                      134.0    1926.216418
# High School Graduate (Age 25+)             134.0    7476.873134
# Bachelor’s Degree (Age 25+)                134.0    8895.097015
# Graduate or Professional Degree (Age 25+)  134.0     624.925373
# English Only                                 0.0            NaN
# Spanish                                      0.0            NaN
# Never Married                              134.0    9849.514925
# Currently Married                          134.0    9514.626866
# Divorced                                   134.0    1343.962687
# zip code tabulation area                   134.0   10701.156716
#
#                                                      std      min        25%  \
# Total Population                            26887.244673   3736.0   32704.00
# Median Age                                      4.887853     25.8      34.80
# Male Population                             12903.088847   1996.0   16636.25
# Female Population                           14115.569858   1740.0   16889.25
# White Alone                                 15097.630907   1074.0    9402.50
# Black or African American Alone             16392.382049     10.0    1589.75
# Asian Alone                                  9516.468054     52.0    1536.75
# Hispanic or Latino                          16001.235103    203.0    6267.00
# Number of Households                         9751.214977   1990.0   13813.00
# Median Household Income                     42293.405948  26400.0   59374.25
# Per Capita Income                           39197.945061  17576.0   31030.75
# Population Below Poverty Level               7810.413579    141.0    3641.25
# Employed                                    12410.224523   2002.0   16182.50
# Unemployed                                   1305.322172     11.0    1160.50
# Total Income Distribution                    9751.214977   1990.0   13813.00
# Median Gross Rent                             581.058874    925.0    1513.25
# Median Home Value                          372011.533897  30800.0  588800.00
# Occupied Housing Units                       9751.214977   1990.0   13813.00
# Vacant Housing Units                         1703.093656     39.0     854.50
# Owner-Occupied Units (value < $100,000)        79.750882      0.0      19.00
# Monthly Housing Costs                         603.233821   1007.0    1575.25
# High School Graduate (Age 25+)               5601.528288     15.0    2853.50
# Bachelor’s Degree (Age 25+)                  5009.905993    597.0    4931.00
# Graduate or Professional Degree (Age 25+)     679.854293      0.0     168.00
# English Only                                         NaN      NaN        NaN
# Spanish                                              NaN      NaN        NaN
# Never Married                                5190.558027    645.0    5995.75
# Currently Married                            5141.548641    678.0    6126.00
# Divorced                                      718.069565     57.0     845.00
# zip code tabulation area                      552.405047  10001.0   10038.25
#
#                                                  50%         75%        max
# Total Population                            51089.50   76292.000   112750.0
# Median Age                                     37.55      41.675       51.9
# Male Population                             24825.50   36278.000    59755.0
# Female Population                           27023.00   40046.500    56197.0
# White Alone                                 17577.00   28094.750    64293.0
# Black or African American Alone              4396.50   17095.500    81608.0
# Asian Alone                                  4041.00    9019.750    57749.0
# Hispanic or Latino                           9820.50   24694.000    85529.0
# Number of Households                        20766.50   29451.500    41653.0
# Median Household Income                     79367.50  107289.500   250001.0
# Per Capita Income                           39966.50   59839.000   191709.0
# Population Below Poverty Level               7483.00   14210.250    31579.0
# Employed                                    25029.00   34401.000    56203.0
# Unemployed                                   1915.00    2891.500     5660.0
# Total Income Distribution                   20766.50   29451.500    41653.0
# Median Gross Rent                            1707.50    2137.000     3501.0
# Median Home Value                          770600.00  991100.000  2000001.0
# Occupied Housing Units                      20766.50   29451.500    41653.0
# Vacant Housing Units                         1615.00    2639.000     9666.0
# Owner-Occupied Units (value < $100,000)        61.00     122.250      467.0
# Monthly Housing Costs                        1789.00    2148.500     4001.0
# High School Graduate (Age 25+)               6526.50   10952.750    30944.0
# Bachelor’s Degree (Age 25+)                  8116.50   12371.250    20984.0
# Graduate or Professional Degree (Age 25+)     408.50     865.250     4185.0
# English Only                                     NaN         NaN        NaN
# Spanish                                          NaN         NaN        NaN
# Never Married                                9589.50   13696.750    23250.0
# Currently Married                            8769.00   12383.250    22277.0
# Divorced                                     1356.50    1905.750     3232.0
# zip code tabulation area                    10469.50   11229.750    11385.0

# %% [markdown]
# ## Make some DF changes
#
# There are some columns which are not useful for us, for example rawHomeStatusCd, marketingStatusSimplifiedCd, etc.

# %%
# Drop rows where the 'price' column has empty values
big_df = big_df.dropna(subset=['price'])

# Verify if rows with empty 'price' are removed
print(f"Shape after removing rows with empty price: {big_df.shape}")
print(big_df['price'].isnull().sum())  # This should return 0
# Out:
# Shape after removing rows with empty price: (18250, 73)
# 0

# %%
big_df['state_hdp'] = big_df['hdpData'].apply(
    lambda x: x.get('homeInfo', {}).get('state') if isinstance(x, dict) else None
)

big_df['addressZipcode'] = big_df['hdpData'].apply(
    lambda x: x.get('homeInfo', {}).get('zipcode') if isinstance(x, dict) else None
)

big_df['addressCity'] = big_df['hdpData'].apply(
    lambda x: x.get('homeInfo', {}).get('city') if isinstance(x, dict) else None
)


print(big_df['state_hdp'].unique())
print('before filtering just NY: ', big_df.shape)
big_df = big_df[big_df['state_hdp'] == 'NY']
print('after filtering just NY: ', big_df.shape)
print(big_df['price'].head())
# Out:
# ['NY' 'CT' 'ON' None 'NJ' 'PA' 'ID' 'MA']
# before filtering just NY:  (18250, 74)
# after filtering just NY:  (18186, 74)
# 0    $2,449/mo
# 1    $2,400/mo
# 2    $2,395/mo
# 3    $2,600/mo
# 4    $2,100/mo
# Name: price, dtype: object

# %%
print(f"Total columns before removing trivially unimportant columns: {big_df.shape[1]}")

big_df_narrowed = big_df.drop(columns=[
    'marketingStatusSimplifiedCd', 'rawHomeStatusCd', 'imgSrc', 'detailUrl',
    'statusType', 'countryCurrency', 'isSaved', 'isUserClaimingOwner',
    'isUserConfirmedClaim', 'pgapt', 'sgapt', 'isShowcaseListing',
    'openHouseStartDate', 'openHouseEndDate', 'isNewYorkState', 'listingType',
    'isFavorite', 'visited', 'rentalMarketingSubType', 'badgeInfo',
    'units', 'lotId', 'isBuilding', 'canSaveBuilding',
    'availabilityCount', 'isInstantTourEnabled', 'isContactable', 'plid',
    'minBeds', 'minBaths', 'buildingId', 'unitCount',
    'minArea', 'isZillowOwned', 'zestimate', 'shouldShowZestimateAsPrice',
    'isHomeRec', 'hasAdditionalAttributions', 'list', 'relaxed',
    'rooms', 'area', 'hasOpenHouse', 'openHouseDescription',
    'priceLabel', 'streetViewURL', 'streetViewMetadataURL'
    ])

print(f"Total columns after removing trivially unimportant columns: {big_df_narrowed.shape[1]}")
big_df_narrowed.head()
# Out:
# Total columns before removing trivially unimportant columns: 74
# Total columns after removing trivially unimportant columns: 27
#          zpid          id providerListingId hasImage          statusText  \
# 0  2081331532  2081331532      g3qqbttyw1g7     True  Apartment for rent
# 1   440689351   440689351     4msp054rpy0w3     True  Apartment for rent
# 2   442762524   442762524     56cyrsnd6f4z1     True  Apartment for rent
# 3  2077973303  2077973303     1v8znm7bxz78f     True  Apartment for rent
# 4    30629385    30629385     5at3ufj2pccje     True  Apartment for rent
#
#        price  unformattedPrice                                       address  \
# 0  $2,449/mo            2449.0  498 Jefferson Ave APT 3B, Brooklyn, NY 11221
# 1  $2,400/mo            2400.0   371 Kosciuszko St APT 1, Brooklyn, NY 11221
# 2  $2,395/mo            2395.0     373 Kosciuszko St #1A, Brooklyn, NY 11221
# 3  $2,600/mo            2600.0       48 Jefferson St #1E, Brooklyn, NY 11206
# 4  $2,100/mo            2100.0         573 Evergreen Ave, Brooklyn, NY 11221
#
#               addressStreet addressCity  ...  \
# 0  498 Jefferson Ave APT 3B    Brooklyn  ...
# 1   371 Kosciuszko St APT 1    Brooklyn  ...
# 2     373 Kosciuszko St #1A    Brooklyn  ...
# 3       48 Jefferson St #1E    Brooklyn  ...
# 4         573 Evergreen Ave    Brooklyn  ...
#
#                                              hdpData has3DModel hasVideo  \
# 0  {'homeInfo': {'zpid': 2081331532, 'streetAddre...      False    False
# 1  {'homeInfo': {'zpid': 440689351, 'streetAddres...      False    False
# 2  {'homeInfo': {'zpid': 442762524, 'streetAddres...      False    False
# 3  {'homeInfo': {'zpid': 2077973303, 'streetAddre...      False    False
# 4  {'homeInfo': {'zpid': 30629385, 'streetAddress...      False    False
#
#    isFeaturedListing     availabilityDate                          brokerName  \
# 0               True  2024-11-21 00:00:00         Listing by: Voro Purple LLC
# 1               True                  NaN         Listing by: Miracle Capital
# 2               True  2024-11-21 00:00:00  Listing by: Skyhigh Realty NYC LLC
# 3               True  2024-11-19 00:00:00         Listing by: Nooklyn NYC LLC
# 4               True  2024-12-01 00:00:00     Listing by: Fifth & Forever LLC
#
#                                       carouselPhotos marketingTreatments  \
# 0  [{'url': 'https://photos.zillowstatic.com/fp/0...              [paid]
# 1  [{'url': 'https://photos.zillowstatic.com/fp/e...              [paid]
# 2  [{'url': 'https://photos.zillowstatic.com/fp/2...              [paid]
# 3  [{'url': 'https://photos.zillowstatic.com/fp/0...              [paid]
# 4  [{'url': 'https://photos.zillowstatic.com/fp/9...              [paid]
#
#    timeOnZillow state_hdp
# 0           NaN        NY
# 1           NaN        NY
# 2           NaN        NY
# 3           NaN        NY
# 4           NaN        NY
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Engineer some trivial attributes
#
# - create houseType from statusText
# - break latlong into 2 seperate latitude and longitude attributes
# - re-create timeOnZillow Attribute. The oringal attribute is null for many houses however the HDP data for the propeorty seems to have that information so we'll use hdp data for it. if hdp data is not availbel we may fall back to zillow's API
# - drop ID columns
# - drop Unformatted price because we have regular price
# - drop address since it is a composite attribute we have street, city, etc. as independent attribute
# -

# %%
def safe_read_subattr(row, attr):
    try:
        return row[attr]
    except (KeyError, TypeError):
        return None

T = TypeVar('T')

def safe_typecast(val, cast: Callable[[object], T]) -> Optional[T]:
    try:
        return cast(val)
    except ValueError:
        return cast()

# %%
big_df_narrowed['houseType'] = big_df_narrowed['statusText'].apply(lambda x: x.split(' ')[0] if x is not None else None)
big_df_narrowed.drop(columns=['statusText'], inplace=True)

big_df_narrowed['latitude'] = big_df_narrowed['latLong'].apply(lambda x: safe_read_subattr(x, 'latitude'))
big_df_narrowed['longitude'] = big_df_narrowed['latLong'].apply(lambda x: safe_read_subattr(x, 'longitude'))
big_df_narrowed.drop(columns=['latLong'], inplace=True)

big_df_narrowed['beds'] = big_df_narrowed['beds'].apply(lambda x: safe_typecast(x, int))
big_df_narrowed['carouselPhotos'] = big_df_narrowed['carouselPhotos'].apply(lambda x: len(x) if x is not None and not isinstance(x, float) else 0)
big_df_narrowed['marketingTreatments'] = big_df_narrowed['marketingTreatments'].apply(lambda x: ''.join(x) if isinstance(x, Iterable) else None)
big_df_narrowed['timeOnZillowText'] = big_df_narrowed['variableData'].apply(lambda x: safe_read_subattr(x, 'text'))
big_df_narrowed['daysOnZillowHDP'] = big_df_narrowed['hdpData'].apply(lambda x: safe_typecast(safe_read_subattr(safe_read_subattr(x, 'homeInfo'), 'daysOnZillow'), int))
big_df_narrowed['timeOnZillowHDP'] = big_df_narrowed['hdpData'].apply(lambda x: safe_read_subattr(safe_read_subattr(x, 'homeInfo'), 'timeOnZillow'))

rent_df = big_df_narrowed.drop(columns=[
    'zpid', 'id', 'unformattedPrice', 'address'
])

# %%
rent_df.shape
# Out:
# (18186, 27)

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18186 entries, 0 to 46793
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   providerListingId     8756 non-null   object
#  1   hasImage              17676 non-null  object
#  2   price                 18186 non-null  object
#  3   addressStreet         8756 non-null   object
#  4   addressCity           18186 non-null  object
#  5   addressState          8756 non-null   object
#  6   addressZipcode        18172 non-null  object
#  7   isUndisclosedAddress  8756 non-null   object
#  8   beds                  18186 non-null  int64
#  9   baths                 18186 non-null  float64
#  10  variableData          18186 non-null  object
#  11  hdpData               18186 non-null  object
#  12  has3DModel            18186 non-null  bool
#  13  hasVideo              18186 non-null  object
#  14  isFeaturedListing     18186 non-null  bool
#  15  availabilityDate      10286 non-null  object
#  16  brokerName            13750 non-null  object
#  17  carouselPhotos        18186 non-null  int64
#  18  marketingTreatments   15494 non-null  object
#  19  timeOnZillow          9430 non-null   float64
#  20  state_hdp             18186 non-null  object
#  21  houseType             18186 non-null  object
#  22  latitude              16667 non-null  float64
#  23  longitude             16667 non-null  float64
#  24  timeOnZillowText      15054 non-null  object
#  25  daysOnZillowHDP       18186 non-null  int64
#  26  timeOnZillowHDP       18186 non-null  int64
# dtypes: bool(2), float64(4), int64(4), object(17)
# memory usage: 3.6+ MB

# %%
# Convert both columns to string type
rent_df['addressZipcode'] = rent_df['addressZipcode'].astype(str)
zip_code_df['zip code tabulation area'] = zip_code_df['zip code tabulation area'].astype(str)

# Now merge
df = pd.merge(rent_df, zip_code_df, 
              left_on='addressZipcode', 
              right_on='zip code tabulation area',
              how='left')

# %%
df.columns
# Out:
# Index(['providerListingId', 'hasImage', 'price', 'addressStreet',
#        'addressCity', 'addressState', 'addressZipcode', 'isUndisclosedAddress',
#        'beds', 'baths', 'variableData', 'hdpData', 'has3DModel', 'hasVideo',
#        'isFeaturedListing', 'availabilityDate', 'brokerName', 'carouselPhotos',
#        'marketingTreatments', 'timeOnZillow', 'state_hdp', 'houseType',
#        'latitude', 'longitude', 'timeOnZillowText', 'daysOnZillowHDP',
#        'timeOnZillowHDP', 'Total Population', 'Median Age', 'Male Population',
#        'Female Population', 'White Alone', 'Black or African American Alone',
#        'Asian Alone', 'Hispanic or Latino', 'Number of Households',
#        'Median Household Income', 'Per Capita Income',
#        'Population Below Poverty Level', 'Employed', 'Unemployed',
#        'Total Income Distribution', 'Median Gross Rent', 'Median Home Value',
#        'Occupied Housing Units', 'Vacant Housing Units',
#        'Owner-Occupied Units (value < $100,000)', 'Monthly Housing Costs',
#        'High School Graduate (Age 25+)', 'Bachelor’s Degree (Age 25+)',
#        'Graduate or Professional Degree (Age 25+)', 'English Only', 'Spanish',
#        'Never Married', 'Currently Married', 'Divorced',
#        'zip code tabulation area'],
#       dtype='object')

# %%
# Clean and preprocess the data
def clean_price(price_str):
    if isinstance(price_str, str):
        # Remove '$', '/', 'mo', and ',','+','C' characters and convert to float
        return float(price_str.replace('$', '').replace('/mo', '').replace(',', '').replace('+', '').replace('C',''))
    return price_str

# %%
# Clean price columns
df['price'] = df['price'].apply(clean_price)
df['Monthly Housing Costs'] = df['Monthly Housing Costs'].apply(clean_price)
df['Median Home Value'] = df['Median Home Value'].apply(clean_price)

# %%
df.to_csv('./merged-rent-census.csv')

# %%
bins = list(range(0, 10000, 1000)) + [float('inf')]  # Bins from 0 to 10,000, step 500, and one bin for values above 10,000
labels = [f"${i}-{i+999}" for i in range(0, 9000, 1000)] + ["$10,000+"]

# Apply the categorization
df['price_category'] = pd.cut(df['price'], bins=bins, labels=labels, right=False)

# Check the result
print(df[['price', 'price_category']].head())
# Out:
#     price price_category
# 0  2449.0     $2000-2999
# 1  2400.0     $2000-2999
# 2  2395.0     $2000-2999
# 3  2600.0     $2000-2999
# 4  2100.0     $2000-2999

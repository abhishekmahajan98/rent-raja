# %%
import usaddress
import string
from Levenshtein import distance as levenshtein_distance
import pandas as pd

# %%
punctuation_without_hash = string.punctuation.replace('#', '')
def remove_punctuation(text):
    try:
        return text.translate(str.maketrans('', '', punctuation_without_hash))
    except AttributeError:
        print(text)
        return text

directional_map = {
    'n': 'north', 'north': 'north',
    's': 'south', 'south': 'south',
    'e': 'east', 'east': 'east',
    'w': 'west', 'west': 'west',
    'ne': 'northeast', 'northeast': 'northeast',
    'nw': 'northwest', 'northwest': 'northwest',
    'se': 'southeast', 'southeast': 'southeast',
    'sw': 'southwest', 'southwest': 'southwest'
}
suffix_map = {
    'st': 'street', 'street': 'street',
    'ave': 'avenue', 'avenue': 'avenue',
    'blvd': 'boulevard', 'boulevard': 'boulevard',
    'rd': 'road', 'road': 'road',
    'dr': 'drive', 'drive': 'drive',
    'ct': 'court', 'court': 'court',
    'pl': 'place', 'place': 'place',
    'ln': 'lane', 'lane': 'lane',
    'ter': 'terrace', 'terrace': 'terrace'
}

def normalize_street_name(street_name):
    # Split the street name into parts
    parts = street_name.lower().split()
    normalized_parts = []

    for part in parts:
        # Remove punctuation
        part_clean = remove_punctuation(part)
        # Normalize directionals and suffixes
        if part_clean in directional_map:
            normalized_parts.append(directional_map[part_clean])
        elif part_clean in suffix_map:
            normalized_parts.append(suffix_map[part_clean])
        else:
            normalized_parts.append(part_clean)
    return ' '.join(normalized_parts)

def normalize_with_usaddress(address):
    try:
        # Clean the address before parsing
        # print(address)
        clean_address = remove_punctuation(address)
        # print(clean_address)
        try:
            parsed = usaddress.tag(clean_address)[0]
        except TypeError:
            print(f"Error parsing address '{address!r}'")

        # print(parsed)
        
        # Normalize StreetNamePreDirectional
        if 'StreetNamePreDirectional' in parsed:
            value = parsed['StreetNamePreDirectional'].lower()
            parsed['StreetNamePreDirectional'] = directional_map.get(value, value)
        
        # Normalize StreetNamePostType
        if 'StreetNamePostType' in parsed:
            value = parsed['StreetNamePostType'].lower()
            parsed['StreetNamePostType'] = suffix_map.get(value, value)
        
        # Normalize StreetName
        if 'StreetName' in parsed:
            parsed['StreetName'] = normalize_street_name(parsed['StreetName'])
        
        # Normalize OccupancyIdentifier
        occupancy_id = parsed.get('OccupancyIdentifier', '')
        if occupancy_id:
            parsed['OccupancyIdentifier'] = remove_punctuation(occupancy_id).lower()
        else:
            # Check for SubaddressIdentifier if OccupancyIdentifier is missing
            subaddress_id = parsed.get('SubaddressIdentifier', '')
            if subaddress_id:
                parsed['OccupancyIdentifier'] = remove_punctuation(subaddress_id).lower()
        
        # Reconstruct the normalized address without OccupancyType
        normalized_address = " ".join(filter(None, [
            parsed.get('AddressNumber', '').lower(),
            parsed.get('StreetNamePreDirectional', '').lower(),
            parsed.get('StreetName', '').lower(),
            parsed.get('StreetNamePostType', '').lower(),
            parsed.get('OccupancyIdentifier', '')
        ])).lower()
        
        return normalized_address
    
    except usaddress.RepeatedLabelError as e:
        # Log the error and return a cleaned, lowercased address
        print(f"Error parsing address '{address}': {e}")
        return remove_punctuation(address).lower()

def are_addresses_same(addr1, addr2, threshold=2):
    norm_addr1 = normalize_with_usaddress(addr1)
    norm_addr2 = normalize_with_usaddress(addr2)
    distance = levenshtein_distance(norm_addr1, norm_addr2)
    return distance <= threshold

# %%
# Example
address1 = "993 Dumont Avenue #2"
address2 = "993 Dumont Ave APT 2"

norm_addr1 = normalize_with_usaddress(address1)
norm_addr2 = normalize_with_usaddress(address2)

print("Normalized Address 1:", norm_addr1)
print("Normalized Address 2:", norm_addr2)
print("Are addresses the same?", are_addresses_same(address1, address2))
# Out:
# Normalized Address 1: 993 dumont avenue # 2
# Normalized Address 2: 993 dumont avenue 2
# Are addresses the same? True

# %%
streeteasy_df = pd.read_csv('streeteasy_listings.csv')
streeteasy_df.head()
# Out:
#         id    listedAt  daysOnMarket availableFrom                   address  \
# 0  4597458  2024-11-25             1    2024-11-25  171 East 96th Street #4A
# 1  4596229  2024-11-22             4    2024-11-22   93 East 96th Street #11
# 2  4596223  2024-11-22             4    2024-11-22    501 Saratoga Avenue #B
# 3  4596221  2024-11-22             4    2024-11-22    501 Saratoga Avenue #C
# 4  4594153  2024-11-20             6    2024-11-20  1115 Willmohr Street #2P
#
#    price   borough neighborhood  zipcode propertyType  ...  longitude  \
# 0   1855  brooklyn  brownsville    11212       rental  ... -73.922293
# 1   2235  brooklyn  brownsville    11212       rental  ... -73.924122
# 2   1750  brooklyn  brownsville    11212       rental  ... -73.917055
# 3   2000  brooklyn  brownsville    11212       rental  ... -73.917055
# 4   1850  brooklyn  brownsville    11212       rental  ... -73.917750
#
#                                            amenities  builtIn  \
# 0  ['fios_available', 'hardwood_floors', 'nyc_eva...     1926
# 1  ['fios_available', 'hardwood_floors', 'live_in...     1926
# 2  ['fios_available', 'hardwood_floors', 'live_in...     1930
# 3  ['fios_available', 'hardwood_floors', 'live_in...     1930
# 4  ['cats', 'doorman', 'elevator', 'fios_availabl...     1961
#
#                                          description          building  \
# 0  Large newly renovated 1-bedroom \n\nFeatures: ...  {'id': '166259'}
# 1  Beautifully newly Renovated Two-Bedroom Apartm...  {'id': '165748'}
# 2  Stunning Newly Renovated One-Bedroom Apartment...  {'id': '140629'}
# 3  Stunning newly renovated two-bedroom apt avail...  {'id': '140629'}
# 4  BIG 1 Bedroom LUXURY APARTMENT\n\nThis 1 bathr...  {'id': '167432'}
#
#                 agents  noFee  \
# 0  ['Voro Purple LLC']  False
# 1    ['Kevin Cameron']  False
# 2    ['Kevin Cameron']  False
# 3    ['Kevin Cameron']  False
# 4  ['Eli Loebenstein']  False
#
#                                               images videos floorplans
# 0  ['https://photos.zillowstatic.com/fp/9deccb9a3...     []         []
# 1  ['https://photos.zillowstatic.com/fp/49380b70a...     []         []
# 2  ['https://photos.zillowstatic.com/fp/e941cdddc...     []         []
# 3  ['https://photos.zillowstatic.com/fp/8189b5ea3...     []         []
# 4  ['https://photos.zillowstatic.com/fp/f7a8a2c7d...     []         []
#
# [5 rows x 25 columns]

# %%
zillow_df = pd.read_csv('rent_data_zillow.csv')
zillow_df.head()
# Out:
#   providerListingId hasImage      price             addressStreet addressCity  \
# 0      g3qqbttyw1g7     True  $2,449/mo  498 Jefferson Ave APT 3B    Brooklyn
# 1     4msp054rpy0w3     True  $2,400/mo   371 Kosciuszko St APT 1    Brooklyn
# 2     56cyrsnd6f4z1     True  $2,395/mo     373 Kosciuszko St #1A    Brooklyn
# 3     1v8znm7bxz78f     True  $2,600/mo       48 Jefferson St #1E    Brooklyn
# 4     5at3ufj2pccje     True  $2,100/mo         573 Evergreen Ave    Brooklyn
#
#   addressState addressZipcode isUndisclosedAddress  beds  baths  ...  \
# 0           NY          11221                False     2    1.0  ...
# 1           NY          11221                False     2    1.0  ...
# 2           NY          11221                False     2    1.0  ...
# 3           NY          11206                False     2    1.0  ...
# 4           NY          11221                False     1    1.0  ...
#
#                            brokerName carouselPhotos  marketingTreatments  \
# 0         Listing by: Voro Purple LLC              5                 paid
# 1         Listing by: Miracle Capital             12                 paid
# 2  Listing by: Skyhigh Realty NYC LLC             11                 paid
# 3         Listing by: Nooklyn NYC LLC             17                 paid
# 4     Listing by: Fifth & Forever LLC             10                 paid
#
#   timeOnZillow  houseType   latitude  longitude  timeOnZillowText  \
# 0          NaN  Apartment  40.684450 -73.937904        2 days ago
# 1          NaN  Apartment  40.692120 -73.940094        3 days ago
# 2          NaN  Apartment  40.692127 -73.940025        2 days ago
# 3          NaN  Apartment  40.698406 -73.933365        4 days ago
# 4          NaN  Apartment  40.689410 -73.913506        2 days ago
#
#   daysOnZillowHDP  timeOnZillowHDP
# 0               2      198026000.0
# 1               3      294307000.0
# 2               2      227011000.0
# 3               4      385412000.0
# 4               2      239925000.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Remove stuff from zillow DF

# %%
zillow_df.drop(columns=['providerListingId', 'hasImage', 'variableData', 'hdpData', 'has3DModel', 'brokerName', 'marketingTreatments', 'timeOnZillow',
'daysOnZillowHDP', 'timeOnZillowHDP', 'daysOnZillowHDP'], inplace=True)

# %% [markdown]
# ## Rename stuff for homegenity

# %%
def convert_to_days(time_str):
    if time_str is None or str(time_str) == 'nan':
        return -1
    try:
        borken_down = time_str.split()
    except AttributeError:
        print(time_str)
        return -1

    if borken_down[1].startswith('day'):
        return int(borken_down[0])
    elif borken_down[1].startswith('hour'):
        return 0
    else:
        return -1

# %%
zillow_df.rename(columns={'addressStreet': 'street', 'addressCity': 'borough', 'addressState': 'state', 'addressZipcode': 'zip', 'carouselPhotos' : 'PhotosNum', 'availabilityDate':
'availableFrom', 'houseType': 'propertyType', 'PhotosNum': 'photosNum'}, inplace=True)
zillow_df['daysOnMarket'] = zillow_df['timeOnZillowText'].apply(lambda x: convert_to_days(x))
zillow_df.drop(columns=['timeOnZillowText'], inplace=True)
zillow_df.head()
# Out:
#        price                    street   borough state    zip  \
# 0  $2,449/mo  498 Jefferson Ave APT 3B  Brooklyn    NY  11221
# 1  $2,400/mo   371 Kosciuszko St APT 1  Brooklyn    NY  11221
# 2  $2,395/mo     373 Kosciuszko St #1A  Brooklyn    NY  11221
# 3  $2,600/mo       48 Jefferson St #1E  Brooklyn    NY  11206
# 4  $2,100/mo         573 Evergreen Ave  Brooklyn    NY  11221
#
#   isUndisclosedAddress  beds  baths hasVideo  isFeaturedListing  \
# 0                False     2    1.0    False               True
# 1                False     2    1.0    False               True
# 2                False     2    1.0    False               True
# 3                False     2    1.0    False               True
# 4                False     1    1.0    False               True
#
#          availableFrom  PhotosNum propertyType   latitude  longitude  \
# 0  2024-11-21 00:00:00          5    Apartment  40.684450 -73.937904
# 1                  NaN         12    Apartment  40.692120 -73.940094
# 2  2024-11-21 00:00:00         11    Apartment  40.692127 -73.940025
# 3  2024-11-19 00:00:00         17    Apartment  40.698406 -73.933365
# 4  2024-12-01 00:00:00         10    Apartment  40.689410 -73.913506
#
#    daysOnMarket
# 0             2
# 1             3
# 2             2
# 3             4
# 4             2

# %% [markdown]
# ## Delete Stuff from streeteasy DF

# %%
streeteasy_df.drop(columns=['id', 'sqft', 'type', 'building', 'agents', 'noFee', 'floorplans',], inplace=True)

# %% [markdown]
# ## Rename Stuff from streeteasy DF

# %%
streeteasy_df
# Out:
#         listedAt  daysOnMarket availableFrom                          address  \
# 0     2024-11-25             1    2024-11-25         171 East 96th Street #4A
# 1     2024-11-22             4    2024-11-22          93 East 96th Street #11
# 2     2024-11-22             4    2024-11-22           501 Saratoga Avenue #B
# 3     2024-11-22             4    2024-11-22           501 Saratoga Avenue #C
# 4     2024-11-20             6    2024-11-20         1115 Willmohr Street #2P
# ...          ...           ...           ...                              ...
# 4095  2024-10-25            32    2024-11-26     187 South Portland Avenue #3
# 4096  2024-10-25            32    2024-10-25       253 Cumberland Street #302
# 4097  2024-10-20            37    2024-11-01             87 Adelphi Street #1
# 4098  2024-09-16            61    2024-12-01  125 South Oxford Street UNIT-2R
# 4099  2024-08-08           110    2024-09-16            183 Lafayette Avenue
#
#       price   borough neighborhood  zipcode propertyType  bedrooms  bathrooms  \
# 0      1855  brooklyn  brownsville    11212       rental         1          1
# 1      2235  brooklyn  brownsville    11212       rental         2          1
# 2      1750  brooklyn  brownsville    11212       rental         1          1
# 3      2000  brooklyn  brownsville    11212       rental         2          1
# 4      1850  brooklyn  brownsville    11212       rental         1          1
# ...     ...       ...          ...      ...          ...       ...        ...
# 4095   3800  brooklyn  fort-greene    11217       rental         2          1
# 4096   2750  brooklyn  fort-greene    11205       rental         1          1
# 4097   3300  brooklyn  fort-greene    11205       rental         1          1
# 4098   3500  brooklyn  fort-greene    11217       rental         1          1
# 4099  16000  brooklyn  fort-greene    11238        house         4          2
#
#        latitude  longitude                                          amenities  \
# 0     40.662186 -73.922293  ['fios_available', 'hardwood_floors', 'nyc_eva...
# 1     40.663817 -73.924122  ['fios_available', 'hardwood_floors', 'live_in...
# 2     40.668506 -73.917055  ['fios_available', 'hardwood_floors', 'live_in...
# 3     40.668506 -73.917055  ['fios_available', 'hardwood_floors', 'live_in...
# 4     40.657349 -73.917750  ['cats', 'doorman', 'elevator', 'fios_availabl...
# ...         ...        ...                                                ...
# 4095  40.683906 -73.973647  ['fios_available', 'hardwood_floors', 'smoke_f...
# 4096  40.688336 -73.972567  ['city_view', 'elevator', 'hardwood_floors', '...
# 4097  40.695201 -73.971962  ['central_ac', 'courtyard', 'dishwasher', 'fio...
# 4098  40.685525 -73.972986  ['city_view', 'dishwasher', 'fios_available', ...
# 4099  40.687899 -73.970194  ['central_ac', 'city_view', 'courtyard', 'dish...
#
#       builtIn                                        description  \
# 0        1926  Large newly renovated 1-bedroom \n\nFeatures: ...
# 1        1926  Beautifully newly Renovated Two-Bedroom Apartm...
# 2        1930  Stunning Newly Renovated One-Bedroom Apartment...
# 3        1930  Stunning newly renovated two-bedroom apt avail...
# 4        1961  BIG 1 Bedroom LUXURY APARTMENT\n\nThis 1 bathr...
# ...       ...                                                ...
# 4095     2002  NO PETS, Hardwood, High Ceilings, Stainless St...
# 4096     1928  Prime location 1 bed\r\n\r\n40x the rent after...
# 4097     2001  87 Adelphi St #1 is a completely renovated gar...
# 4098     1930  Only Two Way to Move in (Rent Special the firs...
# 4099     1899  IMPRESSIVELY DESIGNED | PRIME FORT GREENE | EN...
#
#                                                  images videos
# 0     ['https://photos.zillowstatic.com/fp/9deccb9a3...     []
# 1     ['https://photos.zillowstatic.com/fp/49380b70a...     []
# 2     ['https://photos.zillowstatic.com/fp/e941cdddc...     []
# 3     ['https://photos.zillowstatic.com/fp/8189b5ea3...     []
# 4     ['https://photos.zillowstatic.com/fp/f7a8a2c7d...     []
# ...                                                 ...    ...
# 4095  ['https://photos.zillowstatic.com/fp/50db98f1e...     []
# 4096  ['https://photos.zillowstatic.com/fp/9e9362546...     []
# 4097  ['https://photos.zillowstatic.com/fp/f9f64f35b...     []
# 4098  ['https://photos.zillowstatic.com/fp/39817fd66...     []
# 4099  ['https://photos.zillowstatic.com/fp/acfe3a571...     []
#
# [4100 rows x 18 columns]

# %%
# streeteasy_df.rename(columns={})
streeteasy_df['hasVideo'] = streeteasy_df['videos'].apply(lambda x: 1 if len(x) > 0 else 0)
streeteasy_df['PhotosNum'] = streeteasy_df['images'].apply(lambda x: len(x))
streeteasy_df.drop(columns=['videos', 'images'], inplace=True)
streeteasy_df.rename(columns={'address': 'street', 'zipcode': 'zip', 'property_type': 'propertyType', 'bedrooms':'beds', 'bathrooms':'baths'}, inplace=True)
streeteasy_df.head()
# Out:
#      listedAt  daysOnMarket availableFrom                    street  price  \
# 0  2024-11-25             1    2024-11-25  171 East 96th Street #4A   1855
# 1  2024-11-22             4    2024-11-22   93 East 96th Street #11   2235
# 2  2024-11-22             4    2024-11-22    501 Saratoga Avenue #B   1750
# 3  2024-11-22             4    2024-11-22    501 Saratoga Avenue #C   2000
# 4  2024-11-20             6    2024-11-20  1115 Willmohr Street #2P   1850
#
#     borough neighborhood    zip propertyType  beds  baths   latitude  \
# 0  brooklyn  brownsville  11212       rental     1      1  40.662186
# 1  brooklyn  brownsville  11212       rental     2      1  40.663817
# 2  brooklyn  brownsville  11212       rental     1      1  40.668506
# 3  brooklyn  brownsville  11212       rental     2      1  40.668506
# 4  brooklyn  brownsville  11212       rental     1      1  40.657349
#
#    longitude                                          amenities  builtIn  \
# 0 -73.922293  ['fios_available', 'hardwood_floors', 'nyc_eva...     1926
# 1 -73.924122  ['fios_available', 'hardwood_floors', 'live_in...     1926
# 2 -73.917055  ['fios_available', 'hardwood_floors', 'live_in...     1930
# 3 -73.917055  ['fios_available', 'hardwood_floors', 'live_in...     1930
# 4 -73.917750  ['cats', 'doorman', 'elevator', 'fios_availabl...     1961
#
#                                          description  hasVideo  PhotosNum
# 0  Large newly renovated 1-bedroom \n\nFeatures: ...         1        320
# 1  Beautifully newly Renovated Two-Bedroom Apartm...         1        400
# 2  Stunning Newly Renovated One-Bedroom Apartment...         1        560
# 3  Stunning newly renovated two-bedroom apt avail...         1        400
# 4  BIG 1 Bedroom LUXURY APARTMENT\n\nThis 1 bathr...         1        320

# %%
total_df = pd.concat([streeteasy_df, zillow_df], ignore_index=True)
total_df.head()
# Out:
#      listedAt  daysOnMarket availableFrom                    street price  \
# 0  2024-11-25             1    2024-11-25  171 East 96th Street #4A  1855
# 1  2024-11-22             4    2024-11-22   93 East 96th Street #11  2235
# 2  2024-11-22             4    2024-11-22    501 Saratoga Avenue #B  1750
# 3  2024-11-22             4    2024-11-22    501 Saratoga Avenue #C  2000
# 4  2024-11-20             6    2024-11-20  1115 Willmohr Street #2P  1850
#
#     borough neighborhood    zip propertyType  beds  ...   latitude  longitude  \
# 0  brooklyn  brownsville  11212       rental     1  ...  40.662186 -73.922293
# 1  brooklyn  brownsville  11212       rental     2  ...  40.663817 -73.924122
# 2  brooklyn  brownsville  11212       rental     1  ...  40.668506 -73.917055
# 3  brooklyn  brownsville  11212       rental     2  ...  40.668506 -73.917055
# 4  brooklyn  brownsville  11212       rental     1  ...  40.657349 -73.917750
#
#                                            amenities builtIn  \
# 0  ['fios_available', 'hardwood_floors', 'nyc_eva...  1926.0
# 1  ['fios_available', 'hardwood_floors', 'live_in...  1926.0
# 2  ['fios_available', 'hardwood_floors', 'live_in...  1930.0
# 3  ['fios_available', 'hardwood_floors', 'live_in...  1930.0
# 4  ['cats', 'doorman', 'elevator', 'fios_availabl...  1961.0
#
#                                          description hasVideo PhotosNum  \
# 0  Large newly renovated 1-bedroom \n\nFeatures: ...        1       320
# 1  Beautifully newly Renovated Two-Bedroom Apartm...        1       400
# 2  Stunning Newly Renovated One-Bedroom Apartment...        1       560
# 3  Stunning newly renovated two-bedroom apt avail...        1       400
# 4  BIG 1 Bedroom LUXURY APARTMENT\n\nThis 1 bathr...        1       320
#
#    state isUndisclosedAddress isFeaturedListing
# 0    NaN                  NaN               NaN
# 1    NaN                  NaN               NaN
# 2    NaN                  NaN               NaN
# 3    NaN                  NaN               NaN
# 4    NaN                  NaN               NaN
#
# [5 rows x 21 columns]

# %%
addresses = []
total_df['duplicate'] = False
global failed
failed =  0
def remove_duplicate_custom(row):
    try:
        full_add = normalize_with_usaddress(row['street'])
    except (AttributeError, KeyError):
        print(row)
        failed += 1
        return row

    if full_add is None:
        failed += 1
        return row
    
    for address in addresses:
        if levenshtein_distance(full_add, address) < 3:
            row['duplicate'] = True
            return row
    addresses.append(full_add)
    return row

total_df.drop(6104, inplace=True)

# %%
total_df = total_df.apply(remove_duplicate_custom, axis=1)
print(failed)
print(total_df.columns)
indices_to_drop = total_df[total_df['duplicate'] == True].index
total_df.drop(indices_to_drop, inplace=True)
total_df
# Out:
# Error parsing address '312 E 116th St #PENTHOUSE 2B':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  312 E 116th St #PENTHOUSE 2B
# PARSED TOKENS:    [('312', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('116th', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('2B', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '547 W 47th St #PENTHOUSE 2':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  547 W 47th St #PENTHOUSE 2
# PARSED TOKENS:    [('547', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('47th', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('2', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '1640 Stephen St #TOWNHOUSE 2':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1640 Stephen St #TOWNHOUSE 2
# PARSED TOKENS:    [('1640', 'AddressNumber'), ('Stephen', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('TOWNHOUSE', 'OccupancyType'), ('2', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '1 Leroy St #PENTHOUSE 5B':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1 Leroy St #PENTHOUSE 5B
# PARSED TOKENS:    [('1', 'AddressNumber'), ('Leroy', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('5B', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '119 Leroy St #TOWNHOUSE 3':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  119 Leroy St #TOWNHOUSE 3
# PARSED TOKENS:    [('119', 'AddressNumber'), ('Leroy', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('TOWNHOUSE', 'OccupancyType'), ('3', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '23 E 67th St #PENTHOUSE 6':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  23 E 67th St #PENTHOUSE 6
# PARSED TOKENS:    [('23', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('67th', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('6', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '90-2 Queens Blvd #PENTHOUSE 7':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  902 Queens Blvd #PENTHOUSE 7
# PARSED TOKENS:    [('902', 'AddressNumber'), ('Queens', 'StreetName'), ('Blvd', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('7', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '60-11 83 Pl # FL 3RD':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  6011 83 Pl # FL 3RD
# PARSED TOKENS:    [('6011', 'AddressNumber'), ('83', 'StreetName'), ('Pl', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('FL', 'OccupancyType'), ('3RD', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '346 Lexington Ave #PENTHOUSE 4R':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  346 Lexington Ave #PENTHOUSE 4R
# PARSED TOKENS:    [('346', 'AddressNumber'), ('Lexington', 'StreetName'), ('Ave', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('4R', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '171 N 1st St #TOWNHOUSE 1':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  171 N 1st St #TOWNHOUSE 1
# PARSED TOKENS:    [('171', 'AddressNumber'), ('N', 'StreetNamePreDirectional'), ('1st', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('TOWNHOUSE', 'OccupancyType'), ('1', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '50 W 86th St #PENTHOUSE 1':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  50 W 86th St #PENTHOUSE 1
# PARSED TOKENS:    [('50', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('86th', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('1', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '475 Main Street # FL 1ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  475 Main Street # FL 1ST
# PARSED TOKENS:    [('475', 'AddressNumber'), ('Main', 'StreetName'), ('Street', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('FL', 'OccupancyType'), ('1ST', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '385 Elmwood Avenue # FL 1ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  385 Elmwood Avenue # FL 1ST
# PARSED TOKENS:    [('385', 'AddressNumber'), ('Elmwood', 'StreetName'), ('Avenue', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('FL', 'OccupancyType'), ('1ST', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '1767 Fulton Street # FL 3RD':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1767 Fulton Street # FL 3RD
# PARSED TOKENS:    [('1767', 'AddressNumber'), ('Fulton', 'StreetName'), ('Street', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('FL', 'OccupancyType'), ('3RD', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '147 Lexington Ave #PENTHOUSE 3':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  147 Lexington Ave #PENTHOUSE 3
# PARSED TOKENS:    [('147', 'AddressNumber'), ('Lexington', 'StreetName'), ('Ave', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('3', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '40-22 College Point Blvd #PENTHOUSE 2M':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  4022 College Point Blvd #PENTHOUSE 2M
# PARSED TOKENS:    [('4022', 'AddressNumber'), ('College', 'StreetName'), ('Point', 'StreetName'), ('Blvd', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('2M', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '18 Bridge St #PENTHOUSE 4D':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  18 Bridge St #PENTHOUSE 4D
# PARSED TOKENS:    [('18', 'AddressNumber'), ('Bridge', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('4D', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '26 Avenue A FLOOR 1':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  26 Avenue A FLOOR 1
# PARSED TOKENS:    [('26', 'StreetName'), ('Avenue', 'StreetNamePostType'), ('A', 'OccupancyIdentifier'), ('FLOOR', 'OccupancyType'), ('1', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '49 Spruce 1st Flr St':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  49 Spruce 1st Flr St
# PARSED TOKENS:    [('49', 'AddressNumber'), ('Spruce', 'StreetName'), ('1st', 'AddressNumber'), ('Flr', 'StreetName'), ('St', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '40 W 4th Street #APT 7':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  40 W 4th Street #APT 7
# PARSED TOKENS:    [('40', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('4th', 'StreetName'), ('Street', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('APT', 'OccupancyType'), ('7', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '253 W 28th St #PENTHOUSE 5':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  253 W 28th St #PENTHOUSE 5
# PARSED TOKENS:    [('253', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('28th', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('5', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '10-13 47th Ave #TOWNHOUSE 2':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1013 47th Ave #TOWNHOUSE 2
# PARSED TOKENS:    [('1013', 'AddressNumber'), ('47th', 'StreetName'), ('Ave', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('TOWNHOUSE', 'OccupancyType'), ('2', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '412 County Route 10 #TOWNHOUSE C3':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  412 County Route 10 #TOWNHOUSE C3
# PARSED TOKENS:    [('412', 'AddressNumber'), ('County', 'StreetNamePreType'), ('Route', 'StreetNamePreType'), ('10', 'StreetName'), ('#', 'OccupancyIdentifier'), ('TOWNHOUSE', 'OccupancyType'), ('C3', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '120 Old Post Rd #PENTHOUSE D-406':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  120 Old Post Rd #PENTHOUSE D406
# PARSED TOKENS:    [('120', 'AddressNumber'), ('Old', 'StreetName'), ('Post', 'StreetName'), ('Rd', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PENTHOUSE', 'OccupancyType'), ('D406', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '17 Laura Ln #PHASE I':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  17 Laura Ln #PHASE I
# PARSED TOKENS:    [('17', 'AddressNumber'), ('Laura', 'StreetName'), ('Ln', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('PHASE', 'OccupancyType'), ('I', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '88 Fulton St #TOWNHOUSE 1':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  88 Fulton St #TOWNHOUSE 1
# PARSED TOKENS:    [('88', 'AddressNumber'), ('Fulton', 'StreetName'), ('St', 'StreetNamePostType'), ('#', 'OccupancyIdentifier'), ('TOWNHOUSE', 'OccupancyType'), ('1', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# 0
# Index(['listedAt', 'daysOnMarket', 'availableFrom', 'street', 'price',
#        'borough', 'neighborhood', 'zip', 'propertyType', 'beds', 'baths',
#        'latitude', 'longitude', 'amenities', 'builtIn', 'description',
#        'hasVideo', 'PhotosNum', 'state', 'isUndisclosedAddress',
#        'isFeaturedListing', 'duplicate'],
#       dtype='object')
#          listedAt  daysOnMarket        availableFrom  \
# 0      2024-11-25             1           2024-11-25
# 1      2024-11-22             4           2024-11-22
# 2      2024-11-22             4           2024-11-22
# 4      2024-11-20             6           2024-11-20
# 5      2024-11-19             7           2024-11-19
# ...           ...           ...                  ...
# 22345         NaN             9  2024-11-14 00:00:00
# 22346         NaN            -1  2024-11-15 00:00:00
# 22348         NaN             5  2024-11-18 00:00:00
# 22352         NaN            -1                  NaN
# 22353         NaN            -1                  NaN
#
#                             street      price   borough neighborhood    zip  \
# 0         171 East 96th Street #4A       1855  brooklyn  brownsville  11212
# 1          93 East 96th Street #11       2235  brooklyn  brownsville  11212
# 2           501 Saratoga Avenue #B       1750  brooklyn  brownsville  11212
# 4         1115 Willmohr Street #2P       1850  brooklyn  brownsville  11212
# 5         1075 Clarkson Avenue #2B       3000  brooklyn  brownsville  11212
# ...                            ...        ...       ...          ...    ...
# 22345             12-1 26th Ave #2  $4,400/mo   Astoria          NaN  11102
# 22346       12-20 Astoria Blvd #2A  $3,500/mo   Astoria          NaN  11102
# 22348          11 Maiden Ln APT 6B  $3,750/mo  New York          NaN  10038
# 22352    88 Fulton St #TOWNHOUSE 1  $3,200/mo  New York          NaN  10038
# 22353  111 Fulton St PENTHOUSE 202  $7,995/mo  New York          NaN  10038
#
#       propertyType  beds  ...  longitude  \
# 0           rental     1  ... -73.922293
# 1           rental     2  ... -73.924122
# 2           rental     1  ... -73.917055
# 4           rental     1  ... -73.917750
# 5           rental     3  ... -73.922602
# ...            ...   ...  ...        ...
# 22345    Apartment     4  ... -73.925920
# 22346    Apartment     2  ... -73.929320
# 22348    Apartment     2  ... -74.009330
# 22352    Apartment     1  ... -74.006035
# 22353    Apartment     2  ... -74.006620
#
#                                                amenities  builtIn  \
# 0      ['fios_available', 'hardwood_floors', 'nyc_eva...   1926.0
# 1      ['fios_available', 'hardwood_floors', 'live_in...   1926.0
# 2      ['fios_available', 'hardwood_floors', 'live_in...   1930.0
# 4      ['cats', 'doorman', 'elevator', 'fios_availabl...   1961.0
# 5      ['central_ac', 'fios_available', 'hardwood_flo...   1910.0
# ...                                                  ...      ...
# 22345                                                NaN      NaN
# 22346                                                NaN      NaN
# 22348                                                NaN      NaN
# 22352                                                NaN      NaN
# 22353                                                NaN      NaN
#
#                                              description  hasVideo PhotosNum  \
# 0      Large newly renovated 1-bedroom \n\nFeatures: ...         1       320
# 1      Beautifully newly Renovated Two-Bedroom Apartm...         1       400
# 2      Stunning Newly Renovated One-Bedroom Apartment...         1       560
# 4      BIG 1 Bedroom LUXURY APARTMENT\n\nThis 1 bathr...         1       320
# 5      Newly Renovated – 3BR/1BA in Brownsville on Cl...         1       720
# ...                                                  ...       ...       ...
# 22345                                                NaN     False         0
# 22346                                                NaN     False         0
# 22348                                                NaN     False         5
# 22352                                                NaN     False         0
# 22353                                                NaN     False         0
#
#       state  isUndisclosedAddress isFeaturedListing duplicate
# 0       NaN                   NaN               NaN     False
# 1       NaN                   NaN               NaN     False
# 2       NaN                   NaN               NaN     False
# 4       NaN                   NaN               NaN     False
# 5       NaN                   NaN               NaN     False
# ...     ...                   ...               ...       ...
# 22345    NY                   NaN              True     False
# 22346    NY                   NaN              True     False
# 22348    NY                 False              True     False
# 22352    NY                   NaN              True     False
# 22353    NY                   NaN              True     False
#
# [15784 rows x 22 columns]
